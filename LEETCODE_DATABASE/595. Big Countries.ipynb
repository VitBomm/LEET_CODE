# %% [markdown]
# ![Screenshot%20from%202019-12-19%2008-42-41.png](attachment:Screenshot%20from%202019-12-19%2008-42-41.png)

# %% [markdown]
# https://leetcode.com/problems/big-countries/

# %% [markdown]
# SELECT name, population,area
# FROM World
# Where population > 25000000 or area > 3000000
